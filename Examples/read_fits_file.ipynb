# %%
import sys

from LyaPlotter.file_types import TruthFiles

# %%
randoms = TruthFiles('/project/projectdirs/desi/users/jfarr/LyaCoLoRe_paper//data/picca_input/v9.0.0/zcat_0.1_randoms.fits')
randoms_2 = TruthFiles('/project/projectdirs/desi/users/jfarr/LyaCoLoRe_paper//data/picca_input/v9.0.0/zcat_0.1_randoms_2.fits')
randoms_complete = TruthFiles('/project/projectdirs/desi/users/jfarr/LyaCoLoRe_paper//data/picca_input/v9.0.0/zcat_0.1_randoms_complete.fits')

# %%
randoms.RA
# Out:
# array([ 93.97421143, 250.1957554 , 158.88319543, ..., 137.68119525,
#         39.68690065, 127.95592203])

# %%
randoms.plot_locations()

# %%
randoms_2.plot_locations()

# %%
randoms_complete.plot_locations()

# %%
randoms.plot_footprint()

# %%
randoms_2.plot_footprint()

# %%
randoms_complete.plot_footprint()

# %%
(randoms.RA==randoms_complete.RA).all()
# Out:
# True
